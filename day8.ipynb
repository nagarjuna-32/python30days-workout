# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **OOPS**

# %%
def welcom():
  print("good morning")

welcom()
# Out:
# good morning

# %%
def add(a,b):
  total = a+b
  print("the sum is",total)

c = 10
d = 24
add (c,d)
# Out:
# the sum is 34

# %%
def is_even(n):
    return n % 2 == 0

print(is_even(4))  # True
# Out:
# True

# %%
def maximum(a, b):
    if a > b:
        return a
    return b

# %%
def calculator(a, b, op):
    if op == '+':
        return a + b
    elif op == '-':
        return a - b
    elif op == '*':
        return a * b
    elif op == '/':
        return a / b
