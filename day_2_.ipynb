# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ARTHIMITIC OPERATION**

# %%
x = 100
y = 50
sum = x+y
print(sum)
# Out:
# 150

# %%
sub=x-y
sub
# Out:
# 50

# %%
multi = x*y
multi
# Out:
# 5000

# %%
div = x//y
div
# Out:
# 2

# %%
divi = x/y
divi
# Out:
# 2.0

# %%
a = 4
b= 2

# %% [markdown]
# ### **string operation**

# %%
var = "hello world"
print(var)
# Out:
# hello world

# %%
print(var[4])
# Out:
# o

# %%
print(var[6])
# Out:
# w

# %%
print(var [:5])
# Out:
# hello

# %%
print (var [4:8])
# Out:
# o wo

# %%
len(var)
# Out:
# 11

# %%
num = 5
type(num)
# Out:
# int

# %%
num = 385844.534
type(num)
# Out:
# float

# %%
name  = "arjun"
type(name)
# Out:
# str

# %%
num.real
# Out:
# 385844.534

# %%
num.imag
# Out:
# 0.0

# %%
num = -6544.656
num
# Out:
# -6544.656

# %%
num1 = 10
num2 = 5
# Out:
# 15

# %%
print(num1+num2)
# Out:
# 15

# %%
print(num1-num2)
# Out:
# 5

# %%
print(num1*num2)
# Out:
# 50

# %%
print(num1//num2)
# Out:
# 2

# %%
print(num1**num2)
# Out:
# 100000

# %%
#remainder
print(num1%num2)
# Out:
# 0

# %% [markdown]
# **CONVERSIONS**

# %%
x = "256"
type(x)
# Out:
# str

# %%
int(x)
# Out:
# 256

# %%
print (x)
# Out:
# 256

# %%
x = float(x)

# %%
x
# Out:
# 256.0

# %%
x = complex(x)
print(x)
# Out:
# (256+0j)

# %%
print(complex(2,3))
# Out:
# (2+3j)

# %% [markdown]
# **FUNCTION**

# %%
x = -5454
print(abs(x))
# Out:
# 5454

# %%
import math
x = 10
print(math.exp(x))
# Out:
# 22026.465794806718

# %%
math.e
# Out:
# 2.718281828459045

# %%
math .pi
# Out:
# 3.141592653589793

# %%
print(math.sqrt(9))
# Out:
# 3.0
