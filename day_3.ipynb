# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **creating list**

# %%
num =  [1,2,3,4]

# %%
print (num
       )
# Out:
# [1, 2, 3, 4]

# %%
letter = ["a","b","c","d"]
print(letter)
# Out:
# ['a', 'b', 'c', 'd']

# %%
mix = ["arjun","likhith ","lohith","nagaraj"]
print(mix)
# Out:
# ['arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
mat = [[1,2],[3,4]]
print(mat)
# Out:
# [[1, 2], [3, 4]]

# %% [markdown]
# **accessing the list**

# %%
print(mix)
# Out:
# ['arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
mix[2
  ]
# Out:
# 'lohith'

# %%
mix[-1]
# Out:
# 'nagaraj'

# %%
mix[:3]
# Out:
# ['arjun', 'likhith ', 'lohith']

# %%
mix[1:3]
# Out:
# ['likhith ', 'lohith']

# %%
mix [::2]
# Out:
# ['arjun', 'lohith']

# %%
mix[::-1]
# Out:
# ['nagaraj', 'lohith', 'likhith ', 'arjun']

# %% [markdown]
# **OPeration on list**

# %%
x = [50]*50
print(x)
# Out:
# [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]

# %%
print(letter)
# Out:
# ['a', 'b', 'c', 'd']

# %%
print(mix)
# Out:
# ['arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
conc = letter + mix
print(conc)
# Out:
# ['a', 'b', 'c', 'd', 'arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
var = list("arjun")
print(var)
# Out:
# ['a', 'r', 'j', 'u', 'n']

# %%
one, *other = num
print(one,other)
# Out:
# 1 [2, 3, 4]

# %% [markdown]
# **METHODS IN LIST**

# %%
print(num)
# Out:
# [1, 2, 3, 4]

# %%
num.append(5)

# %%
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
num.extend(mix)

# %%
print(num)
# Out:
# [1, 2, 3, 4, 5, 'arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
num.insert(5,"naga")
print(num)
# Out:
# [1, 2, 3, 4, 5, 'naga', 'arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
num.remove("naga")
num
# Out:
# [1, 2, 3, 4, 5, 'arjun', 'likhith ', 'lohith', 'nagaraj']

# %%
var1 = ['s','f','r','a','h']
var1.sort()

# %%
print(var1)
# Out:
# ['a', 'f', 'h', 'r', 's']
